# %%
from faker import Faker
import pandas as pd

fake = Faker('es_ES') # Configuración regional

df = pd.read_csv("Datasets/datos_sensibles.csv")

# Anonimización
df["Nombre"] = [fake.name() for _ in range(len(df))]

df["email"] = [fake.email() for _ in range(len(df))]
df["telefono"] = [fake.phone_number() for _ in range(len(df))]

df
# Out:
#                                          id      tipo_documento  \
# 0      a9c38334-d87a-481d-bf00-19a02049d658           Pasaporte
# 1      20d5b5d9-f53c-49cb-be72-5a02a7876c29                 RUC
# 2      375d4948-54d9-4b06-9ccf-227d65e83daa  Carnet Extranjería
# 3      8babb04e-770e-4d15-98f3-91f52ca547f0           Pasaporte
# 4      063d6f35-8ef8-403d-bed4-ddf1ff05b96b                 RUC
# ...                                     ...                 ...
# 99995  09abbd82-f92c-4b10-9c78-a10a95362153                 RUC
# 99996  aa7529a8-b957-4473-9f08-912ecd96f3e3  Carnet Extranjería
# 99997  b3c57fd5-1820-4de0-a783-f48c4fce0d41           Pasaporte
# 99998  22e01682-3329-4ec5-afde-990e52bdef8e                 RUC
# 99999  f8a3bcc9-f1ef-436d-8d4a-eb37cb5a7fc8  Carnet Extranjería
#
#        numero_documento        nombre  apellido  \
# 0              46470118      Apolinar    Amores
# 1              93596211        Elodia    Tolosa
# 2              95226745       Adelina  Gelabert
# ...
